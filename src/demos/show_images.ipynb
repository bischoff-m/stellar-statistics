# %% [markdown]
# ## Show Image Files

# %%
from star_field_analyser.definitions import Paths
from star_field_analyser.image import RawImage

# %%
img = RawImage(Paths.observations / "2024-11-05/IMG_3320.CR2").load()

# %% [markdown]
# ### Raw Image Data
#
# Use `preview()` to downscale the image and `show()` to display the image.

# %%
print("Image size", (img.metadata.width, img.metadata.height))
img.raw().preview().show()
# Out:
# Image size (5202, 3465)
# <PIL.Image.Image image mode=L size=800x532>

# %% [markdown]
# ### Comparison of RGB conversion methods

# %%
img.to_rgb_rawkit().preview().show()
img.to_rgb_cv2().preview().show()
# Out:
# <PIL.Image.Image image mode=RGB size=800x532>
# <PIL.Image.Image image mode=RGB size=800x532>

# %% [markdown]
# ### Mask colors in raw image
#
# Assumes the filter pattern of the Bayer filter is RGGB.
#
# <!-- ![Bayer sensor](attachment:image.png) -->

# %%
img_green = img.raw().channel("green")
img_green.preview().show()
img_green.save(Paths.data / "sky_green_only.png")
# Out:
# <PIL.Image.Image image mode=L size=800x532>

# %%
img_green = img.raw().green_interpolated()
img_green.save(Paths.data / "sky_green_interpolated.png")
img_green.preview().show()
# Out:
# <PIL.Image.Image image mode=L size=800x532>
