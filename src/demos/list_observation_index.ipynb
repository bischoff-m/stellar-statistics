# %% [markdown]
# # List Observations and Image Properties

# %%
from celestializer.definitions import Paths
from celestializer.image import RawImage
from celestializer import list_observations, raw_to_df

# %%
files = list_observations()
df = raw_to_df(files)
df
# Out:
#                                              filepath  width  height  \
# 0                  calibration/2024-11-05/black_1.CR2   5202    3465
# 1                  calibration/2024-11-05/black_2.CR2   5202    3465
# 2                  calibration/2024-11-05/white_1.CR2   5202    3465
# 3                 calibration/2025-01-05/vignette.dng   4080    3072
# 4                observations/2024-11-05/IMG_3316.CR2   5202    3465
# 5                observations/2024-11-05/IMG_3318.CR2   5202    3465
# 6                observations/2024-11-05/IMG_3319.CR2   5202    3465
# 7                observations/2024-11-05/IMG_3320.CR2   5202    3465
# 8                observations/2024-11-05/IMG_3321.CR2   5202    3465
# 9                observations/2024-11-05/IMG_3322.CR2   5202    3465
# 10               observations/2024-11-05/IMG_3323.CR2   5202    3465
# 11               observations/2024-11-05/IMG_3324.CR2   5202    3465
# 12               observations/2024-11-05/IMG_3325.CR2   5202    3465
# ...

# %%
img = RawImage(Paths.observations / "2024-11-05/IMG_3320.CR2").load()
img.metadata.model_dump()
# Out:
# {'width': 5202,
#  'height': 3465,
#  'focal_length': 18.0,
#  'aperture': 3.5,
#  'shutter': 10.0,
#  'iso': 6400,
#  'timestamp': datetime.datetime(2024, 11, 5, 0, 37, 58),
#  'camera': 'Canon EOS 1200D',
#  'bit_depth': 14}
